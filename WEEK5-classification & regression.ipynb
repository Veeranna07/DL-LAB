# %% [markdown]
# # Regression

# %%
# Import Libraries
from pandas import read_csv
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
# load dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/abalone.csv'
dataframe = read_csv(url, header=None)
dataset = dataframe.values

# %%
# split into input (X) and output (y) variables
X, y = dataset[:, 1:-1], dataset[:, -1]
X, y = X.astype('float'), y.astype('float')
n_features = X.shape[1]

# %%
# split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# %%
# define the keras model
model = Sequential()
model.add(Dense(20, input_dim=n_features, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(10, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='linear'))

# %%
# compile the keras model
model.compile(loss='mse', optimizer='adam')

# %%
# fit the keras model on the dataset
model.fit(X_train, y_train, epochs=150, batch_size=32, verbose=2)
# Out:
# Epoch 1/150
# 88/88 - 1s - loss: 82.5891 - 1s/epoch - 13ms/step
# Epoch 2/150
# 88/88 - 0s - loss: 24.1548 - 188ms/epoch - 2ms/step
# Epoch 3/150
# 88/88 - 0s - loss: 9.2337 - 141ms/epoch - 2ms/step
# Epoch 4/150
# 88/88 - 0s - loss: 7.8752 - 141ms/epoch - 2ms/step
# Epoch 5/150
# 88/88 - 0s - loss: 6.9406 - 156ms/epoch - 2ms/step
# Epoch 6/150
# 88/88 - 0s - loss: 6.5471 - 141ms/epoch - 2ms/step
# Epoch 7/150
# 88/88 - 0s - loss: 6.3781 - 156ms/epoch - 2ms/step
# Epoch 8/150
# 88/88 - 0s - loss: 6.2935 - 141ms/epoch - 2ms/step
# Epoch 9/150
# 88/88 - 0s - loss: 6.2086 - 156ms/epoch - 2ms/step
# Epoch 10/150
# 88/88 - 0s - loss: 6.1208 - 141ms/epoch - 2ms/step
# Epoch 11/150
# 88/88 - 0s - loss: 6.0401 - 156ms/epoch - 2ms/step
# Epoch 12/150
# 88/88 - 0s - loss: 6.0016 - 156ms/epoch - 2ms/step
# Epoch 13/150
# 88/88 - 0s - loss: 5.9382 - 141ms/epoch - 2ms/step
# Epoch 14/150
# 88/88 - 0s - loss: 5.8391 - 156ms/epoch - 2ms/step
# Epoch 15/150
# 88/88 - 0s - loss: 5.7812 - 141ms/epoch - 2ms/step
# Epoch 16/150
# 88/88 - 0s - loss: 5.7147 - 156ms/epoch - 2ms/step
# Epoch 17/150
# 88/88 - 0s - loss: 5.6651 - 141ms/epoch - 2ms/step
# Epoch 18/150
# 88/88 - 0s - loss: 5.5968 - 141ms/epoch - 2ms/step
# Epoch 19/150
# 88/88 - 0s - loss: 5.5333 - 141ms/epoch - 2ms/step
# Epoch 20/150
# 88/88 - 0s - loss: 5.4641 - 141ms/epoch - 2ms/step
# Epoch 21/150
# 88/88 - 0s - loss: 5.4540 - 156ms/epoch - 2ms/step
# Epoch 22/150
# 88/88 - 0s - loss: 5.3649 - 141ms/epoch - 2ms/step
# Epoch 23/150
# 88/88 - 0s - loss: 5.3162 - 156ms/epoch - 2ms/step
# Epoch 24/150
# 88/88 - 0s - loss: 5.2843 - 141ms/epoch - 2ms/step
# Epoch 25/150
# 88/88 - 0s - loss: 5.2443 - 156ms/epoch - 2ms/step
# Epoch 26/150
# 88/88 - 0s - loss: 5.2511 - 141ms/epoch - 2ms/step
# Epoch 27/150
# 88/88 - 0s - loss: 5.1938 - 156ms/epoch - 2ms/step
# Epoch 28/150
# 88/88 - 0s - loss: 5.1640 - 141ms/epoch - 2ms/step
# Epoch 29/150
# 88/88 - 0s - loss: 5.1446 - 156ms/epoch - 2ms/step
# Epoch 30/150
# 88/88 - 0s - loss: 5.1075 - 156ms/epoch - 2ms/step
# Epoch 31/150
# 88/88 - 0s - loss: 5.0901 - 141ms/epoch - 2ms/step
# Epoch 32/150
# 88/88 - 0s - loss: 5.0878 - 141ms/epoch - 2ms/step
# Epoch 33/150
# 88/88 - 0s - loss: 5.0538 - 141ms/epoch - 2ms/step
# Epoch 34/150
# 88/88 - 0s - loss: 5.0820 - 156ms/epoch - 2ms/step
# Epoch 35/150
# 88/88 - 0s - loss: 5.0481 - 141ms/epoch - 2ms/step
# Epoch 36/150
# 88/88 - 0s - loss: 5.0165 - 156ms/epoch - 2ms/step
# Epoch 37/150
# 88/88 - 0s - loss: 5.0320 - 141ms/epoch - 2ms/step
# Epoch 38/150
# 88/88 - 0s - loss: 5.0339 - 141ms/epoch - 2ms/step
# Epoch 39/150
# 88/88 - 0s - loss: 5.0110 - 156ms/epoch - 2ms/step
# Epoch 40/150
# 88/88 - 0s - loss: 5.0043 - 141ms/epoch - 2ms/step
# Epoch 41/150
# 88/88 - 0s - loss: 5.0358 - 156ms/epoch - 2ms/step
# Epoch 42/150
# 88/88 - 0s - loss: 5.0032 - 141ms/epoch - 2ms/step
# Epoch 43/150
# 88/88 - 0s - loss: 4.9775 - 141ms/epoch - 2ms/step
# Epoch 44/150
# 88/88 - 0s - loss: 4.9819 - 156ms/epoch - 2ms/step
# Epoch 45/150
# 88/88 - 0s - loss: 4.9783 - 141ms/epoch - 2ms/step
# Epoch 46/150
# 88/88 - 0s - loss: 4.9587 - 188ms/epoch - 2ms/step
# Epoch 47/150
# 88/88 - 0s - loss: 4.9773 - 156ms/epoch - 2ms/step
# Epoch 48/150
# 88/88 - 0s - loss: 4.9798 - 141ms/epoch - 2ms/step
# Epoch 49/150
# 88/88 - 0s - loss: 4.9526 - 156ms/epoch - 2ms/step
# Epoch 50/150
# 88/88 - 0s - loss: 4.9778 - 141ms/epoch - 2ms/step
# Epoch 51/150
# 88/88 - 0s - loss: 4.9396 - 156ms/epoch - 2ms/step
# Epoch 52/150
# 88/88 - 0s - loss: 4.9650 - 141ms/epoch - 2ms/step
# Epoch 53/150
# 88/88 - 0s - loss: 4.9458 - 141ms/epoch - 2ms/step
# Epoch 54/150
# 88/88 - 0s - loss: 4.9341 - 141ms/epoch - 2ms/step
# Epoch 55/150
# 88/88 - 0s - loss: 4.9716 - 141ms/epoch - 2ms/step
# Epoch 56/150
# 88/88 - 0s - loss: 4.9417 - 141ms/epoch - 2ms/step
# Epoch 57/150
# 88/88 - 0s - loss: 4.9370 - 141ms/epoch - 2ms/step
# Epoch 58/150
# 88/88 - 0s - loss: 4.9309 - 141ms/epoch - 2ms/step
# Epoch 59/150
# 88/88 - 0s - loss: 4.9118 - 141ms/epoch - 2ms/step
# Epoch 60/150
# 88/88 - 0s - loss: 4.9461 - 138ms/epoch - 2ms/step
# Epoch 61/150
# 88/88 - 0s - loss: 4.9099 - 156ms/epoch - 2ms/step
# Epoch 62/150
# 88/88 - 0s - loss: 4.9200 - 141ms/epoch - 2ms/step
# Epoch 63/150
# 88/88 - 0s - loss: 4.9046 - 141ms/epoch - 2ms/step
# Epoch 64/150
# 88/88 - 0s - loss: 4.9097 - 156ms/epoch - 2ms/step
# Epoch 65/150
# 88/88 - 0s - loss: 4.9095 - 141ms/epoch - 2ms/step
# Epoch 66/150
# 88/88 - 0s - loss: 4.8944 - 141ms/epoch - 2ms/step
# Epoch 67/150
# 88/88 - 0s - loss: 4.9173 - 141ms/epoch - 2ms/step
# Epoch 68/150
# 88/88 - 0s - loss: 4.8894 - 141ms/epoch - 2ms/step
# Epoch 69/150
# 88/88 - 0s - loss: 4.8892 - 141ms/epoch - 2ms/step
# Epoch 70/150
# 88/88 - 0s - loss: 4.8724 - 156ms/epoch - 2ms/step
# Epoch 71/150
# 88/88 - 0s - loss: 4.9104 - 141ms/epoch - 2ms/step
# Epoch 72/150
# 88/88 - 0s - loss: 4.8729 - 156ms/epoch - 2ms/step
# Epoch 73/150
# 88/88 - 0s - loss: 4.8583 - 141ms/epoch - 2ms/step
# Epoch 74/150
# 88/88 - 0s - loss: 4.8512 - 156ms/epoch - 2ms/step
# Epoch 75/150
# 88/88 - 0s - loss: 4.8964 - 141ms/epoch - 2ms/step
# Epoch 76/150
# 88/88 - 0s - loss: 4.8397 - 156ms/epoch - 2ms/step
# Epoch 77/150
# 88/88 - 0s - loss: 4.8411 - 141ms/epoch - 2ms/step
# Epoch 78/150
# 88/88 - 0s - loss: 4.8325 - 156ms/epoch - 2ms/step
# Epoch 79/150
# 88/88 - 0s - loss: 4.8321 - 141ms/epoch - 2ms/step
# Epoch 80/150
# 88/88 - 0s - loss: 4.8234 - 156ms/epoch - 2ms/step
# Epoch 81/150
# 88/88 - 0s - loss: 4.8337 - 141ms/epoch - 2ms/step
# Epoch 82/150
# 88/88 - 0s - loss: 4.8642 - 153ms/epoch - 2ms/step
# Epoch 83/150
# 88/88 - 0s - loss: 4.8068 - 141ms/epoch - 2ms/step
# Epoch 84/150
# 88/88 - 0s - loss: 4.8034 - 156ms/epoch - 2ms/step
# Epoch 85/150
# 88/88 - 0s - loss: 4.7955 - 141ms/epoch - 2ms/step
# Epoch 86/150
# 88/88 - 0s - loss: 4.8380 - 141ms/epoch - 2ms/step
# Epoch 87/150
# 88/88 - 0s - loss: 4.7871 - 156ms/epoch - 2ms/step
# Epoch 88/150
# 88/88 - 0s - loss: 4.7804 - 141ms/epoch - 2ms/step
# Epoch 89/150
# 88/88 - 0s - loss: 4.7896 - 188ms/epoch - 2ms/step
# Epoch 90/150
# 88/88 - 0s - loss: 4.7846 - 156ms/epoch - 2ms/step
# Epoch 91/150
# 88/88 - 0s - loss: 4.7693 - 141ms/epoch - 2ms/step
# Epoch 92/150
# 88/88 - 0s - loss: 4.7928 - 156ms/epoch - 2ms/step
# Epoch 93/150
# 88/88 - 0s - loss: 4.8027 - 141ms/epoch - 2ms/step
# Epoch 94/150
# 88/88 - 0s - loss: 4.7693 - 156ms/epoch - 2ms/step
# Epoch 95/150
# 88/88 - 0s - loss: 4.7546 - 141ms/epoch - 2ms/step
# Epoch 96/150
# 88/88 - 0s - loss: 4.7582 - 156ms/epoch - 2ms/step
# Epoch 97/150
# 88/88 - 0s - loss: 4.7450 - 156ms/epoch - 2ms/step
# Epoch 98/150
# 88/88 - 0s - loss: 4.7501 - 141ms/epoch - 2ms/step
# Epoch 99/150
# 88/88 - 0s - loss: 4.7808 - 156ms/epoch - 2ms/step
# Epoch 100/150
# 88/88 - 0s - loss: 4.7362 - 141ms/epoch - 2ms/step
# Epoch 101/150
# 88/88 - 0s - loss: 4.7407 - 141ms/epoch - 2ms/step
# Epoch 102/150
# 88/88 - 0s - loss: 4.7243 - 156ms/epoch - 2ms/step
# Epoch 103/150
# 88/88 - 0s - loss: 4.7296 - 141ms/epoch - 2ms/step
# Epoch 104/150
# 88/88 - 0s - loss: 4.7212 - 156ms/epoch - 2ms/step
# Epoch 105/150
# 88/88 - 0s - loss: 4.7521 - 141ms/epoch - 2ms/step
# Epoch 106/150
# 88/88 - 0s - loss: 4.7171 - 141ms/epoch - 2ms/step
# Epoch 107/150
# 88/88 - 0s - loss: 4.7153 - 156ms/epoch - 2ms/step
# Epoch 108/150
# 88/88 - 0s - loss: 4.7047 - 140ms/epoch - 2ms/step
# Epoch 109/150
# 88/88 - 0s - loss: 4.7057 - 157ms/epoch - 2ms/step
# Epoch 110/150
# 88/88 - 0s - loss: 4.7113 - 141ms/epoch - 2ms/step
# Epoch 111/150
# 88/88 - 0s - loss: 4.6885 - 156ms/epoch - 2ms/step
# Epoch 112/150
# 88/88 - 0s - loss: 4.6885 - 141ms/epoch - 2ms/step
# Epoch 113/150
# 88/88 - 0s - loss: 4.6910 - 141ms/epoch - 2ms/step
# Epoch 114/150
# 88/88 - 0s - loss: 4.6737 - 156ms/epoch - 2ms/step
# Epoch 115/150
# 88/88 - 0s - loss: 4.6677 - 141ms/epoch - 2ms/step
# Epoch 116/150
# 88/88 - 0s - loss: 4.6894 - 156ms/epoch - 2ms/step
# Epoch 117/150
# 88/88 - 0s - loss: 4.6715 - 141ms/epoch - 2ms/step
# Epoch 118/150
# 88/88 - 0s - loss: 4.6673 - 156ms/epoch - 2ms/step
# Epoch 119/150
# 88/88 - 0s - loss: 4.6618 - 156ms/epoch - 2ms/step
# Epoch 120/150
# 88/88 - 0s - loss: 4.6621 - 141ms/epoch - 2ms/step
# Epoch 121/150
# 88/88 - 0s - loss: 4.6827 - 156ms/epoch - 2ms/step
# Epoch 122/150
# 88/88 - 0s - loss: 4.6453 - 141ms/epoch - 2ms/step
# Epoch 123/150
# 88/88 - 0s - loss: 4.6421 - 141ms/epoch - 2ms/step
# Epoch 124/150
# 88/88 - 0s - loss: 4.6681 - 156ms/epoch - 2ms/step
# Epoch 125/150
# 88/88 - 0s - loss: 4.6526 - 141ms/epoch - 2ms/step
# Epoch 126/150
# 88/88 - 0s - loss: 4.6310 - 156ms/epoch - 2ms/step
# Epoch 127/150
# 88/88 - 0s - loss: 4.6309 - 188ms/epoch - 2ms/step
# Epoch 128/150
# 88/88 - 0s - loss: 4.6357 - 141ms/epoch - 2ms/step
# Epoch 129/150
# 88/88 - 0s - loss: 4.6373 - 156ms/epoch - 2ms/step
# Epoch 130/150
# 88/88 - 0s - loss: 4.6535 - 141ms/epoch - 2ms/step
# Epoch 131/150
# 88/88 - 0s - loss: 4.6546 - 141ms/epoch - 2ms/step
# Epoch 132/150
# 88/88 - 0s - loss: 4.6482 - 156ms/epoch - 2ms/step
# Epoch 133/150
# 88/88 - 0s - loss: 4.6718 - 141ms/epoch - 2ms/step
# Epoch 134/150
# 88/88 - 0s - loss: 4.6232 - 141ms/epoch - 2ms/step
# Epoch 135/150
# 88/88 - 0s - loss: 4.6375 - 141ms/epoch - 2ms/step
# Epoch 136/150
# 88/88 - 0s - loss: 4.6142 - 156ms/epoch - 2ms/step
# Epoch 137/150
# 88/88 - 0s - loss: 4.6269 - 141ms/epoch - 2ms/step
# Epoch 138/150
# 88/88 - 0s - loss: 4.6222 - 156ms/epoch - 2ms/step
# Epoch 139/150
# 88/88 - 0s - loss: 4.5988 - 141ms/epoch - 2ms/step
# Epoch 140/150
# 88/88 - 0s - loss: 4.6611 - 156ms/epoch - 2ms/step
# Epoch 141/150
# 88/88 - 0s - loss: 4.6251 - 141ms/epoch - 2ms/step
# Epoch 142/150
# 88/88 - 0s - loss: 4.5843 - 141ms/epoch - 2ms/step
# Epoch 143/150
# 88/88 - 0s - loss: 4.6479 - 141ms/epoch - 2ms/step
# Epoch 144/150
# 88/88 - 0s - loss: 4.6222 - 141ms/epoch - 2ms/step
# Epoch 145/150
# 88/88 - 0s - loss: 4.5940 - 141ms/epoch - 2ms/step
# Epoch 146/150
# 88/88 - 0s - loss: 4.6019 - 156ms/epoch - 2ms/step
# Epoch 147/150
# 88/88 - 0s - loss: 4.5833 - 141ms/epoch - 2ms/step
# Epoch 148/150
# 88/88 - 0s - loss: 4.6152 - 141ms/epoch - 2ms/step
# Epoch 149/150
# 88/88 - 0s - loss: 4.6374 - 141ms/epoch - 2ms/step
# Epoch 150/150
# 88/88 - 0s - loss: 4.6217 - 141ms/epoch - 2ms/step

# %%
# evaluate on test set
yhat = model.predict(X_test)
error = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % error)
# Out:
# 44/44 [==============================] - 0s 2ms/step
# MAE: 1.502

# %% [markdown]
# # Classification

# %%
# classification mlp model for the abalone dataset
from numpy import unique
from numpy import argmax
from pandas import read_csv
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
# load dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/abalone.csv'
dataframe = read_csv(url, header=None)
dataset = dataframe.values

# %%
# split into input (X) and output (y) variables
X, y = dataset[:, 1:-1], dataset[:, -1]
X, y = X.astype('float'), y.astype('float')
n_features = X.shape[1]

# %%
# encode strings to integer
y = LabelEncoder().fit_transform(y)
n_class = len(unique(y))

# %%
# split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# %%
# define the keras model
model = Sequential()
model.add(Dense(20, input_dim=n_features, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(10, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(n_class, activation='softmax'))

# %%
# compile the keras model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')

# %%
# fit the keras model on the dataset
model.fit(X_train, y_train, epochs=150, batch_size=32, verbose=2)
# Out:
# Epoch 1/150
# 88/88 - 1s - loss: 3.1537 - 1s/epoch - 12ms/step
# Epoch 2/150
# 88/88 - 0s - loss: 2.7065 - 156ms/epoch - 2ms/step
# Epoch 3/150
# 88/88 - 0s - loss: 2.5526 - 151ms/epoch - 2ms/step
# Epoch 4/150
# 88/88 - 0s - loss: 2.4688 - 166ms/epoch - 2ms/step
# Epoch 5/150
# 88/88 - 0s - loss: 2.3845 - 145ms/epoch - 2ms/step
# Epoch 6/150
# 88/88 - 0s - loss: 2.3130 - 150ms/epoch - 2ms/step
# Epoch 7/150
# 88/88 - 0s - loss: 2.2619 - 142ms/epoch - 2ms/step
# Epoch 8/150
# 88/88 - 0s - loss: 2.2271 - 142ms/epoch - 2ms/step
# Epoch 9/150
# 88/88 - 0s - loss: 2.2034 - 168ms/epoch - 2ms/step
# Epoch 10/150
# 88/88 - 0s - loss: 2.1876 - 206ms/epoch - 2ms/step
# Epoch 11/150
# 88/88 - 0s - loss: 2.1729 - 143ms/epoch - 2ms/step
# Epoch 12/150
# 88/88 - 0s - loss: 2.1624 - 166ms/epoch - 2ms/step
# Epoch 13/150
# 88/88 - 0s - loss: 2.1563 - 151ms/epoch - 2ms/step
# Epoch 14/150
# 88/88 - 0s - loss: 2.1443 - 173ms/epoch - 2ms/step
# Epoch 15/150
# 88/88 - 0s - loss: 2.1348 - 184ms/epoch - 2ms/step
# Epoch 16/150
# 88/88 - 0s - loss: 2.1314 - 183ms/epoch - 2ms/step
# Epoch 17/150
# 88/88 - 0s - loss: 2.1240 - 147ms/epoch - 2ms/step
# Epoch 18/150
# 88/88 - 0s - loss: 2.1168 - 170ms/epoch - 2ms/step
# Epoch 19/150
# 88/88 - 0s - loss: 2.1108 - 176ms/epoch - 2ms/step
# Epoch 20/150
# 88/88 - 0s - loss: 2.1054 - 170ms/epoch - 2ms/step
# Epoch 21/150
# 88/88 - 0s - loss: 2.1004 - 174ms/epoch - 2ms/step
# Epoch 22/150
# 88/88 - 0s - loss: 2.0930 - 160ms/epoch - 2ms/step
# Epoch 23/150
# 88/88 - 0s - loss: 2.0879 - 197ms/epoch - 2ms/step
# Epoch 24/150
# 88/88 - 0s - loss: 2.0820 - 161ms/epoch - 2ms/step
# Epoch 25/150
# 88/88 - 0s - loss: 2.0772 - 149ms/epoch - 2ms/step
# Epoch 26/150
# 88/88 - 0s - loss: 2.0726 - 152ms/epoch - 2ms/step
# Epoch 27/150
# 88/88 - 0s - loss: 2.0690 - 159ms/epoch - 2ms/step
# Epoch 28/150
# 88/88 - 0s - loss: 2.0614 - 158ms/epoch - 2ms/step
# Epoch 29/150
# 88/88 - 0s - loss: 2.0563 - 143ms/epoch - 2ms/step
# Epoch 30/150
# 88/88 - 0s - loss: 2.0532 - 141ms/epoch - 2ms/step
# Epoch 31/150
# 88/88 - 0s - loss: 2.0476 - 159ms/epoch - 2ms/step
# Epoch 32/150
# 88/88 - 0s - loss: 2.0445 - 158ms/epoch - 2ms/step
# Epoch 33/150
# 88/88 - 0s - loss: 2.0388 - 145ms/epoch - 2ms/step
# Epoch 34/150
# 88/88 - 0s - loss: 2.0339 - 163ms/epoch - 2ms/step
# Epoch 35/150
# 88/88 - 0s - loss: 2.0298 - 154ms/epoch - 2ms/step
# Epoch 36/150
# 88/88 - 0s - loss: 2.0266 - 156ms/epoch - 2ms/step
# Epoch 37/150
# 88/88 - 0s - loss: 2.0217 - 161ms/epoch - 2ms/step
# Epoch 38/150
# 88/88 - 0s - loss: 2.0182 - 138ms/epoch - 2ms/step
# Epoch 39/150
# 88/88 - 0s - loss: 2.0148 - 146ms/epoch - 2ms/step
# Epoch 40/150
# 88/88 - 0s - loss: 2.0114 - 154ms/epoch - 2ms/step
# Epoch 41/150
# 88/88 - 0s - loss: 2.0087 - 157ms/epoch - 2ms/step
# Epoch 42/150
# 88/88 - 0s - loss: 2.0052 - 151ms/epoch - 2ms/step
# Epoch 43/150
# 88/88 - 0s - loss: 2.0045 - 142ms/epoch - 2ms/step
# Epoch 44/150
# 88/88 - 0s - loss: 2.0009 - 143ms/epoch - 2ms/step
# Epoch 45/150
# 88/88 - 0s - loss: 1.9964 - 160ms/epoch - 2ms/step
# Epoch 46/150
# 88/88 - 0s - loss: 1.9939 - 152ms/epoch - 2ms/step
# Epoch 47/150
# 88/88 - 0s - loss: 1.9911 - 143ms/epoch - 2ms/step
# Epoch 48/150
# 88/88 - 0s - loss: 1.9887 - 143ms/epoch - 2ms/step
# Epoch 49/150
# 88/88 - 0s - loss: 1.9862 - 157ms/epoch - 2ms/step
# Epoch 50/150
# 88/88 - 0s - loss: 1.9842 - 159ms/epoch - 2ms/step
# Epoch 51/150
# 88/88 - 0s - loss: 1.9830 - 143ms/epoch - 2ms/step
# Epoch 52/150
# 88/88 - 0s - loss: 1.9816 - 185ms/epoch - 2ms/step
# Epoch 53/150
# 88/88 - 0s - loss: 1.9770 - 155ms/epoch - 2ms/step
# Epoch 54/150
# 88/88 - 0s - loss: 1.9743 - 141ms/epoch - 2ms/step
# Epoch 55/150
# 88/88 - 0s - loss: 1.9746 - 150ms/epoch - 2ms/step
# Epoch 56/150
# 88/88 - 0s - loss: 1.9738 - 159ms/epoch - 2ms/step
# Epoch 57/150
# 88/88 - 0s - loss: 1.9714 - 160ms/epoch - 2ms/step
# Epoch 58/150
# 88/88 - 0s - loss: 1.9710 - 157ms/epoch - 2ms/step
# Epoch 59/150
# 88/88 - 0s - loss: 1.9667 - 141ms/epoch - 2ms/step
# Epoch 60/150
# 88/88 - 0s - loss: 1.9658 - 159ms/epoch - 2ms/step
# Epoch 61/150
# 88/88 - 0s - loss: 1.9673 - 158ms/epoch - 2ms/step
# Epoch 62/150
# 88/88 - 0s - loss: 1.9657 - 159ms/epoch - 2ms/step
# Epoch 63/150
# 88/88 - 0s - loss: 1.9635 - 159ms/epoch - 2ms/step
# Epoch 64/150
# 88/88 - 0s - loss: 1.9603 - 157ms/epoch - 2ms/step
# Epoch 65/150
# 88/88 - 0s - loss: 1.9612 - 142ms/epoch - 2ms/step
# Epoch 66/150
# 88/88 - 0s - loss: 1.9614 - 146ms/epoch - 2ms/step
# Epoch 67/150
# 88/88 - 0s - loss: 1.9582 - 155ms/epoch - 2ms/step
# Epoch 68/150
# 88/88 - 0s - loss: 1.9564 - 158ms/epoch - 2ms/step
# Epoch 69/150
# 88/88 - 0s - loss: 1.9571 - 148ms/epoch - 2ms/step
# Epoch 70/150
# 88/88 - 0s - loss: 1.9570 - 153ms/epoch - 2ms/step
# Epoch 71/150
# 88/88 - 0s - loss: 1.9563 - 155ms/epoch - 2ms/step
# Epoch 72/150
# 88/88 - 0s - loss: 1.9549 - 162ms/epoch - 2ms/step
# Epoch 73/150
# 88/88 - 0s - loss: 1.9534 - 155ms/epoch - 2ms/step
# Epoch 74/150
# 88/88 - 0s - loss: 1.9548 - 150ms/epoch - 2ms/step
# Epoch 75/150
# 88/88 - 0s - loss: 1.9556 - 152ms/epoch - 2ms/step
# Epoch 76/150
# 88/88 - 0s - loss: 1.9519 - 142ms/epoch - 2ms/step
# Epoch 77/150
# 88/88 - 0s - loss: 1.9502 - 151ms/epoch - 2ms/step
# Epoch 78/150
# 88/88 - 0s - loss: 1.9488 - 166ms/epoch - 2ms/step
# Epoch 79/150
# 88/88 - 0s - loss: 1.9490 - 151ms/epoch - 2ms/step
# Epoch 80/150
# 88/88 - 0s - loss: 1.9522 - 158ms/epoch - 2ms/step
# Epoch 81/150
# 88/88 - 0s - loss: 1.9490 - 143ms/epoch - 2ms/step
# Epoch 82/150
# 88/88 - 0s - loss: 1.9493 - 157ms/epoch - 2ms/step
# Epoch 83/150
# 88/88 - 0s - loss: 1.9476 - 159ms/epoch - 2ms/step
# Epoch 84/150
# 88/88 - 0s - loss: 1.9481 - 158ms/epoch - 2ms/step
# Epoch 85/150
# 88/88 - 0s - loss: 1.9472 - 157ms/epoch - 2ms/step
# Epoch 86/150
# 88/88 - 0s - loss: 1.9464 - 142ms/epoch - 2ms/step
# Epoch 87/150
# 88/88 - 0s - loss: 1.9452 - 143ms/epoch - 2ms/step
# Epoch 88/150
# 88/88 - 0s - loss: 1.9471 - 158ms/epoch - 2ms/step
# Epoch 89/150
# 88/88 - 0s - loss: 1.9469 - 200ms/epoch - 2ms/step
# Epoch 90/150
# 88/88 - 0s - loss: 1.9447 - 150ms/epoch - 2ms/step
# Epoch 91/150
# 88/88 - 0s - loss: 1.9446 - 159ms/epoch - 2ms/step
# Epoch 92/150
# 88/88 - 0s - loss: 1.9431 - 142ms/epoch - 2ms/step
# Epoch 93/150
# 88/88 - 0s - loss: 1.9451 - 159ms/epoch - 2ms/step
# Epoch 94/150
# 88/88 - 0s - loss: 1.9449 - 158ms/epoch - 2ms/step
# Epoch 95/150
# 88/88 - 0s - loss: 1.9446 - 144ms/epoch - 2ms/step
# Epoch 96/150
# 88/88 - 0s - loss: 1.9431 - 142ms/epoch - 2ms/step
# Epoch 97/150
# 88/88 - 0s - loss: 1.9438 - 158ms/epoch - 2ms/step
# Epoch 98/150
# 88/88 - 0s - loss: 1.9401 - 157ms/epoch - 2ms/step
# Epoch 99/150
# 88/88 - 0s - loss: 1.9440 - 159ms/epoch - 2ms/step
# Epoch 100/150
# 88/88 - 0s - loss: 1.9411 - 142ms/epoch - 2ms/step
# Epoch 101/150
# 88/88 - 0s - loss: 1.9425 - 161ms/epoch - 2ms/step
# Epoch 102/150
# 88/88 - 0s - loss: 1.9411 - 148ms/epoch - 2ms/step
# Epoch 103/150
# 88/88 - 0s - loss: 1.9396 - 166ms/epoch - 2ms/step
# Epoch 104/150
# 88/88 - 0s - loss: 1.9406 - 150ms/epoch - 2ms/step
# Epoch 105/150
# 88/88 - 0s - loss: 1.9400 - 144ms/epoch - 2ms/step
# Epoch 106/150
# 88/88 - 0s - loss: 1.9407 - 154ms/epoch - 2ms/step
# Epoch 107/150
# 88/88 - 0s - loss: 1.9409 - 150ms/epoch - 2ms/step
# Epoch 108/150
# 88/88 - 0s - loss: 1.9411 - 154ms/epoch - 2ms/step
# Epoch 109/150
# 88/88 - 0s - loss: 1.9378 - 143ms/epoch - 2ms/step
# Epoch 110/150
# 88/88 - 0s - loss: 1.9401 - 161ms/epoch - 2ms/step
# Epoch 111/150
# 88/88 - 0s - loss: 1.9383 - 155ms/epoch - 2ms/step
# Epoch 112/150
# 88/88 - 0s - loss: 1.9389 - 158ms/epoch - 2ms/step
# Epoch 113/150
# 88/88 - 0s - loss: 1.9381 - 150ms/epoch - 2ms/step
# Epoch 114/150
# 88/88 - 0s - loss: 1.9390 - 158ms/epoch - 2ms/step
# Epoch 115/150
# 88/88 - 0s - loss: 1.9380 - 142ms/epoch - 2ms/step
# Epoch 116/150
# 88/88 - 0s - loss: 1.9372 - 166ms/epoch - 2ms/step
# Epoch 117/150
# 88/88 - 0s - loss: 1.9361 - 150ms/epoch - 2ms/step
# Epoch 118/150
# 88/88 - 0s - loss: 1.9398 - 144ms/epoch - 2ms/step
# Epoch 119/150
# 88/88 - 0s - loss: 1.9366 - 142ms/epoch - 2ms/step
# Epoch 120/150
# 88/88 - 0s - loss: 1.9370 - 150ms/epoch - 2ms/step
# Epoch 121/150
# 88/88 - 0s - loss: 1.9378 - 150ms/epoch - 2ms/step
# Epoch 122/150
# 88/88 - 0s - loss: 1.9366 - 157ms/epoch - 2ms/step
# Epoch 123/150
# 88/88 - 0s - loss: 1.9366 - 159ms/epoch - 2ms/step
# Epoch 124/150
# 88/88 - 0s - loss: 1.9360 - 165ms/epoch - 2ms/step
# Epoch 125/150
# 88/88 - 0s - loss: 1.9375 - 151ms/epoch - 2ms/step
# Epoch 126/150
# 88/88 - 0s - loss: 1.9367 - 197ms/epoch - 2ms/step
# Epoch 127/150
# 88/88 - 0s - loss: 1.9370 - 135ms/epoch - 2ms/step
# Epoch 128/150
# 88/88 - 0s - loss: 1.9363 - 153ms/epoch - 2ms/step
# Epoch 129/150
# 88/88 - 0s - loss: 1.9336 - 154ms/epoch - 2ms/step
# Epoch 130/150
# 88/88 - 0s - loss: 1.9335 - 150ms/epoch - 2ms/step
# Epoch 131/150
# 88/88 - 0s - loss: 1.9353 - 152ms/epoch - 2ms/step
# Epoch 132/150
# 88/88 - 0s - loss: 1.9332 - 154ms/epoch - 2ms/step
# Epoch 133/150
# 88/88 - 0s - loss: 1.9355 - 155ms/epoch - 2ms/step
# Epoch 134/150
# 88/88 - 0s - loss: 1.9338 - 158ms/epoch - 2ms/step
# Epoch 135/150
# 88/88 - 0s - loss: 1.9321 - 148ms/epoch - 2ms/step
# Epoch 136/150
# 88/88 - 0s - loss: 1.9347 - 158ms/epoch - 2ms/step
# Epoch 137/150
# 88/88 - 0s - loss: 1.9346 - 152ms/epoch - 2ms/step
# Epoch 138/150
# 88/88 - 0s - loss: 1.9359 - 142ms/epoch - 2ms/step
# Epoch 139/150
# 88/88 - 0s - loss: 1.9329 - 143ms/epoch - 2ms/step
# Epoch 140/150
# 88/88 - 0s - loss: 1.9322 - 158ms/epoch - 2ms/step
# Epoch 141/150
# 88/88 - 0s - loss: 1.9357 - 159ms/epoch - 2ms/step
# Epoch 142/150
# 88/88 - 0s - loss: 1.9348 - 141ms/epoch - 2ms/step
# Epoch 143/150
# 88/88 - 0s - loss: 1.9361 - 158ms/epoch - 2ms/step
# Epoch 144/150
# 88/88 - 0s - loss: 1.9364 - 158ms/epoch - 2ms/step
# Epoch 145/150
# 88/88 - 0s - loss: 1.9329 - 145ms/epoch - 2ms/step
# Epoch 146/150
# 88/88 - 0s - loss: 1.9334 - 151ms/epoch - 2ms/step
# Epoch 147/150
# 88/88 - 0s - loss: 1.9337 - 152ms/epoch - 2ms/step
# Epoch 148/150
# 88/88 - 0s - loss: 1.9317 - 155ms/epoch - 2ms/step
# Epoch 149/150
# 88/88 - 0s - loss: 1.9324 - 158ms/epoch - 2ms/step
# Epoch 150/150
# 88/88 - 0s - loss: 1.9333 - 150ms/epoch - 2ms/step

# %%
# evaluate on test set
yhat = model.predict(X_test)
yhat = argmax(yhat, axis=-1).astype('int')
acc = accuracy_score(y_test, yhat)
print('Accuracy: %.3f' % acc)
# Out:
# 44/44 [==============================] - 0s 3ms/step
# Accuracy: 0.280
